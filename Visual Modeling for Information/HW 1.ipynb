# %% [markdown]
# # Visual Modeling for Information
# ## Homework 1
# Team Members:
# * Jesús Catzín
# * Héctor Hernández
# * Isaac Chavez
# * Monserrat Valbuena

# %%
# Importing Libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ### XLSX Format
# * Data Source: https://catalogue.data.gov.bc.ca/dataset/bc-schools-grade-to-grade-transition/resource/c7aea2bd-8aa4-414c-b045-03da7ecd75a3

# %%
xlsx = pd.read_excel("data/grtogrtransition_2011-12_to_2020-21.xlsx") #loading file
xlsx.drop(columns="Unnamed: 0", inplace =True) #Deleting a index column
xlsx.head() #showing first 5 rows
# Out:
#    BASE_YEAR SCHOOL_YEAR      DATA_LEVEL PUBLIC_OR_INDEPENDENT  \
# 0  2010/2011   2011/2012  Province Level      Province - Total
# 1  2010/2011   2011/2012  Province Level      Province - Total
# 2  2010/2011   2011/2012  Province Level      Province - Total
# 3  2010/2011   2011/2012  Province Level      Province - Total
# 4  2010/2011   2011/2012  Province Level      Province - Total
#
#    DISTRICT_NUMBER DISTRICT_NAME  SCHOOL_NUMBER SCHOOL_NAME  STUDENT_GRADE  \
# 0              NaN           NaN            NaN         NaN              1
# 1              NaN           NaN            NaN         NaN              1
# 2              NaN           NaN            NaN         NaN              1
# 3              NaN           NaN            NaN         NaN              1
# 4              NaN           NaN            NaN         NaN              1
#
#       SUB_POPULATION       FACILITY_TYPE                    MEASURE_NAME  \
# ...

# %% [markdown]
# ### SQL Server
#
# As explained in the description file, SQL Server may appear as a file format in some databases but in reality is a collection of other file formats that can be imported to SQL server, in this case due the fact that it is not a data set, we used the xls format to work with.

# %% [markdown]
# * Data Source: https://www.inegi.org.mx/app/descarga/

# %%
xls = pd.ExcelFile("data/envi2014_diccionario.xls") # equivalent to read_excel(ExcelFile, …)
sheetX = xls.parse(1, skiprows = 4) # access to the numer of sheet and skip the rows that you need
sheetX.head() # view the Data Frame
# Out:
#         Tabla                                         Pregunta Mnemónico  \
# 0         NaN                                              NaN       NaN
# 1  T_VIV_PPAL                                Número de control   control
# 2         NaN                  Número de vivienda seleccionada   viv_sel
# 3         NaN  3.18 ¿El dueño o propietario de esta vivienda….     p3_18
# 4         NaN                                              NaN       NaN
#
#    Longitud Tipo de Dato     Rangos Validos Unnamed: 6           Metadatos
# 0       NaN          NaN                NaN         Id               Valor
# 1       7.0     CARÁCTER  [0140007-3260031]        NaN                 NaN
# 2       2.0     CARÁCTER            [01-24]        NaN                 NaN
# 3       1.0     CARÁCTER              [1-7]          1  1=la compró nueva?
# 4       NaN          NaN                NaN          2  2=la compró usada?

# %% [markdown]
# ### SAS
# * Data Source: https://www.inegi.org.mx/app/descarga/
# * Dataset: https://www.inegi.org.mx/contenidos/programas/intercensal/2015/microdatos/eic2015_01_sas.zip

# %%
sas = pd.read_sas("data/tr_persona01.sas7bdat") #loading file
sas.head() #showing first five rows
# Out:
#          ID_VIV    ID_PERSONA    ENT            NOM_ENT     MUN  \
# 0  1.001000e+10  1.001000e+12  b'01'  b'Aguascalientes'  b'001'
# 1  1.001000e+10  1.001000e+12  b'01'  b'Aguascalientes'  b'001'
# 2  1.001000e+10  1.001000e+12  b'01'  b'Aguascalientes'  b'001'
# 3  1.001000e+10  1.001000e+12  b'01'  b'Aguascalientes'  b'001'
# 4  1.001000e+10  1.001000e+12  b'01'  b'Aguascalientes'  b'001'
#
#              NOM_MUN   LOC50K            NOM_LOC  COBERTURA       ESTRATO  \
# 0  b'Aguascalientes'  b'0001'  b'Aguascalientes'        2.0  b'01-001-05'
# 1  b'Aguascalientes'  b'0001'  b'Aguascalientes'        2.0  b'01-001-05'
# 2  b'Aguascalientes'  b'0001'  b'Aguascalientes'        2.0  b'01-001-05'
# 3  b'Aguascalientes'  b'0001'  b'Aguascalientes'        2.0  b'01-001-05'
# 4  b'Aguascalientes'  b'0001'  b'Aguascalientes'        2.0  b'01-001-06'
#
#    ... HIJOS_NAC_VIVOS  HIJOS_FALLECIDOS  HIJOS_SOBREVIV  FECHA_NAC_M  \
# ...

# %%
sas2 = pd.read_sas("data/tr_vivienda01.sas7bdat") #loading file
sas2.head() #showing first five rows
# Out:
#          ID_VIV    ENT            NOM_ENT     MUN            NOM_MUN   LOC50K  \
# 0  1.001000e+10  b'01'  b'Aguascalientes'  b'001'  b'Aguascalientes'  b'0001'
# 1  1.001000e+10  b'01'  b'Aguascalientes'  b'001'  b'Aguascalientes'  b'0001'
# 2  1.001000e+10  b'01'  b'Aguascalientes'  b'001'  b'Aguascalientes'  b'0001'
# 3  1.001000e+10  b'01'  b'Aguascalientes'  b'001'  b'Aguascalientes'  b'0000'
# 4  1.001000e+10  b'01'  b'Aguascalientes'  b'001'  b'Aguascalientes'  b'0001'
#
#                                       NOM_LOC  COBERTURA       ESTRATO  \
# 0                           b'Aguascalientes'        2.0  b'01-001-05'
# 1                           b'Aguascalientes'        2.0  b'01-001-06'
# 2                           b'Aguascalientes'        2.0  b'01-001-05'
# 3  b'Localidad de menos de 50 mil habitantes'        2.0  b'01-001-16'
# 4                           b'Aguascalientes'        2.0  b'01-001-01'
#
# ...
